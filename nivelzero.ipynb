# %% [markdown]
# ![fb97a6ff4bb0a0f10f33b8020b3ff13218955a5d08a04a11cc4cc26f745fb468.jpg](attachment:fb97a6ff4bb0a0f10f33b8020b3ff13218955a5d08a04a11cc4cc26f745fb468.jpg)

# %% [markdown]
#  # **Nivel Zero**

# %% [markdown]
# ![princ.webp](attachment:princ.webp)

# %% [markdown]
# #### Importar a biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# #### Carregar os dados

# %%
url = "dataset/aluguel.csv"
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %% [markdown]
# #### Visualizar os tipos dos dados

# %%
print(type(url))
# Out:
# <class 'str'>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - str - é string (texto)
# - int - são números inteiros
# - float - são números reais

# %% [markdown]
# ### "Não existem acidentes"
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# # Fontes de Dados

# %% [markdown]
# As fontes de dados fazem parte do nosso treinamento. A arte de entendê-las é a chave fundamental para destruir seus maiores e perigosos inimigos.

# %% [markdown]
# Dentre as fontes de dados que podemos citar, algumas são muito populares:
#
# - CSV
# - XLSX
# - JSON
# - HTML
# - SQL
# - XML
# - ENTRE OUTRAS

# %% [markdown]
# É nas fontes de dados que temos nossos maiores desafios.

# %% [markdown]
# Entendê-las faz parte do treinamento, para explorar e encontra anomalias e conseguir limpar os dados para realizar consultas específicas e preparar os dados para a equipe de Machine Learning.

# %% [markdown]
# # Equipe de ML-Web Django

# %% [markdown]
# ![kung-fu-panda-4.jpg](attachment:kung-fu-panda-4.jpg)

# %% [markdown]
# Algumas perguntas tem que ser respondidas?

# %% [markdown]
# - O que é .HTML?
# - O que é .CSS ?
# - O que é .CSV ?
# - O que é .TXT ?
# - O que é .JSON ?
# - O que é .XML ?
# - O que é .XLSX ?
# - O que é SQL?
# - O que é Framework ?
# - O que é Django ?
# - O que é Machine Learning?
# - O que é Data Science?
# - É possível prever o futuro?
# - Resolvendo os desafios das minhas tarefas de DC, ajudará a equipe de ML-Django?

# %% [markdown]
# # **CSV**

# %% [markdown]
# - CSV são arquivos especiais  e muito utilizados no setor público do Distrito Federal. Aqui a sede do governo brasileiro, com diversos ministérios e orgãos públicos. Possui também, uma diversidade de sistemas e linguagens de programação, nessa complexidade de tipos e categorias de sistemas, arquivos como csv auxilia na comunicação e integração dos dados.

# %% [markdown]
# - CSV - são arquivos separados por vírgulas

# %%
pd.read_csv(url,sep=";")
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# Heverton Anunciação em seu livro "O cientista de dados e os seus demônios" traz as seguintes perguntas:
# - Quais engenheiros de softwares são esses?
# - De onde vêm esses cientistas de dados?
# - Como eles vivem?
# - O que eles comem?
# - Como se reproduzem?

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# "Para que algo seja especial, é só tem  acreditar que ela é especial"
# ![images.jpg](attachment:images.jpg)

# %% [markdown]
# "Não existe ingrediente secreto" Kungfu pandas

# %% [markdown]
# Amilcar Netto enfatiza que a biblioteca pandas é uma abstração de outra biblioteca "NumPy"

# %% [markdown]
# ![image.png](attachment:image.png)
# - Heverton anunciaçaõ traz a seguinte mensagem:
#
# - 70% do tempo do cientista de dados é limpeza e preparação de dados.

# %% [markdown]
# # Nivel Um

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# # **Exercício 1**
# -Mostre o cabeçalho do dataset

# %% [markdown]
# ##### **gabarito - ex 1**

# %%
# primeiro crie uma variável df que representa dataframe

df = pd.read_csv(url,sep=";")

# mostre o dataframe com seus primeiros cinco registros (cabeçalho)

df.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# "Sabedoria e intuições digitais são ferramentas de abstração importante para um cientista de dados" Rômulo C. Silvestre

# %% [markdown]
# # NumPy

# %% [markdown]
# ![Tigress.webp](attachment:Tigress.webp)

# %% [markdown]
# Dados são produzidos a todo momento, sejam eles coletados ou gerados, por quase todos os eventos e nos mais diversos formatos.

# %% [markdown]
# A ciência de dados é a junção de outras áreas^
#
# - Análise de Dados
# - Administrador de Banco de Dados (DBA)
# - Matemática
# - Estatística
# - Ciência da Computação

# %% [markdown]
# NumPy é uma biblioteca que facilita a realização de cáculos cientificos, e também , a manipulação de dados.
# Ela fornece:
# - Recursos para análise numérica
# - Álgebra linear
# - Cálculos matriciais
# - Entre outras funcionalidades.
# - Permite abstrair diversos procedimentos matemáticos complexos.

# %%
import numpy as np

# Lista de valores de vendas de imóveis (em milhares de reais)
vendas_imoveis = [350, 450, 500, 600, 700]

# Calculando a média de vendas usando NumPy
media_vendas = np.mean(vendas_imoveis)

print(f'A média de vendas de imóveis é: {media_vendas} mil reais')
# Out:
# A média de vendas de imóveis é: 520.0 mil reais

# %% [markdown]
# # Scikit-Learn

# %% [markdown]
# ![KFP3-promo-crane1.webp](attachment:KFP3-promo-crane1.webp)

# %% [markdown]
# A biblioteca Scikit-Learn é o padrão de fato no mercado para Machine Learnin, implementando um grande número de algoritmos para essa área , poupando tempo e envitando erros para os cientistas de dados, que de outra forma, teriam que implementá-los manualmente.

# %% [markdown]
# A equipe de machine learning trabalha:
# - Escolhendo o melhor algoritmo para prever o futuro
# - O tipo de aprendizado (supervisionado e não supervionado)
# - Separa 70/30
# - Coloca para treinar
# - Avalia os resultados e o modelo
# - Realiza otimizações no modelo

# %% [markdown]
# # Matplolib

# %% [markdown]
# ![png-clipart-po-crane-monkey-tigress-mantis-kung-fu-panda-technic-kung-fu-thumbnail.png](attachment:png-clipart-po-crane-monkey-tigress-mantis-kung-fu-panda-technic-kung-fu-thumbnail.png)

# %% [markdown]
# O Matplotlib é uma biblioteca para gerar gráficos de diversos tipos.

# %% [markdown]
# # Linguagem Python

# %% [markdown]
# ![viper.webp](attachment:viper.webp)

# %% [markdown]
# A linguagem python é uma linguagem multiparadigma aplicada em diversas áreas , desde programação IoT , Android, Web , Ciência de Dados, Inteligência Artificial e nanotecnologia entre outras.

# %% [markdown]
# Nela você pode aplicar os paradigmas:
#
# - Orientado a Objetos
# - Funcional
# - Estruturado
#
# Além desses paradigmas , pode programar utilizando células de notebook. Como estamos programando agora.

# %% [markdown]
# Cite cinco características que você acha interesssante no Python:
#
# -Responda aqui na célula
# _______________________________________________
# _______________________________________________

# %% [markdown]
# ## Gabarito

# %% [markdown]
# A linguagem tem as seguintes características:
#
# - Mutliplataforma
# - Usos diversos
# - Identação
# - Tipagem dinâmica
# - Vasta quantidade de bibliotecas

# %% [markdown]
# # Exercício - Quais comentários temos no Python?

# %% [markdown]
# Responda aqui!

# %%
# Este comentário é de uma linha

# %%
"""
    Múltiplas linhas
    
"""
imovel = "lindo em Copacana" 
imovel
# Out:
# 'lindo em Copacana'

# %% [markdown]
# # Exercício

# %% [markdown]
# Leia o nome do usuário e mostre o valor lido

# %% [markdown]
# #### Gabarito

# %%
nome = input("Qual o seu nome")
nome
# Out:
# 'Rômulo'

# %% [markdown]
# # Exercício - Leia a idade do cliente da nossa imobiliária

# %% [markdown]
# responda ...

# %% [markdown]
# #### Gabarito

# %%
idade = int(input("Qual a sua idade?"))
idade
# Out:
# 45

# %% [markdown]
# # Tipagem

# %% [markdown]
# """
# Arquivo de Exemplo: Tipos de Dados em Python
#
# Este arquivo demonstra os principais tipos de dados em Python e como utilizá-los.
#
# 1. Tipos Numéricos:
#    - int: Números inteiros
#    - float: Números de ponto flutuante
#
# 2. Tipo Booleano:
#    - bool: Valores booleanos (True ou False)
#
# 3. Tipo String:
#    - str: Sequências de caracteres
#
# 4. Tipo Nulo:
#    - None: Representa a ausência de valor
#
# 5. Operadores 'is' e 'is not':
#    - Utilizados para verificar identidade de objetos, especialmente úteis com None.
#
# 6. Função type():
#    - Utilizada para obter o tipo de um objeto.
#
# """

# %% [markdown]
# # SciPy

# %% [markdown]
# ![495px-MantisKFP2.webp](attachment:495px-MantisKFP2.webp)

# %% [markdown]
# O que é SciPy?
#
# - Biblioteca de Ferramentas Científicas: SciPy fornece muitas funções que lidam com álgebra linear, otimização, integração, interpolação, equações diferenciais e outras tarefas científicas e de engenharia.
# - Baseado em NumPy: SciPy é construído sobre NumPy e fornece muitas funções que operam em arrays NumPy, o que facilita a manipulação de grandes conjuntos de dados numéricos.

# %% [markdown]
# # Vamos voltar para o nosso estágio

# %% [markdown]
# #### Exercício - Mostre 23 registros no cabeçalho

# %% [markdown]
# Responda?

# %% [markdown]
# **Gabarito**

# %%
df.head(23)
# Out:
#                        Tipo                   Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete               Copacabana        1      0       0
# 1                      Casa          Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala          Barra da Tijuca        0      4       0
# 3               Apartamento                   Centro        1      0       0
# 4               Apartamento             Higienópolis        1      0       0
# 5               Apartamento             Vista Alegre        3      1       0
# 6               Apartamento                 Cachambi        2      0       0
# 7        Casa de Condomínio          Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                    Ramos        2      2       0
# 9   Conjunto Comercial/Sala                   Centro        0      3       0
# 10              Apartamento                   Centro        1      0       0
# ...

# %% [markdown]
# Exercício - Mostre o final do DataFrame

# %%
# Gabarito
df.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %% [markdown]
# Exercício - Qual a diferença entre Series e DataFrames?

# %% [markdown]
# Gabarito:
#
# Series é um objeto array unidimensional
# Dataframe é uma matriz bidimensional rotulada, ou seja, para a qual podem ser atribuídos rótulos (nomes)  aos seus atributos (colunas) e indices númericos às suas linhas.

# %% [markdown]
# Exercício - Considere uma lista de anos de lançamento de um imóvel. Insira os valores em Series

# %%
# Gabarito

lancamentos = pd.Series([2024,2025,2026,2027])
lancamentos
# Out:
# 0    2024
# 1    2025
# 2    2026
# 3    2027
# dtype: int64

# %% [markdown]
# **Gabarito - tupla**

# %%
lancamentos = pd.Series((2024,2025,2026,2027))
lancamentos
# Out:
# 0    2024
# 1    2025
# 2    2026
# 3    2027
# dtype: int64

# %% [markdown]
# #### Exercício - Crie series com dicionário

# %%
lancamentos = pd.Series({'jan':2024,'fev':2025,'mar':2026,'abr':2027})
lancamentos
# Out:
# jan    2024
# fev    2025
# mar    2026
# abr    2027
# dtype: int64

# %% [markdown]
# #### Exercício - Como examinar a quantidade de linhas do dataframe?

# %% [markdown]
# Gabarito

# %%
# antes vamos ver o tipo
df.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %% [markdown]
# **Gabarito**

# %%
# vamos ver quantidade de linhas do dataframe
len(df)
# Out:
# 32960

# %% [markdown]
# ### Acesse apenas a coluna Suites

# %%
df['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
df.Valor[2:4]
# Out:
# 2    5200.0
# 3     800.0
# Name: Valor, dtype: float64

# %% [markdown]
# Orientação a Objetos
#
# - Classe
# - Objeto
# - Método
# - Herança
# - Encpsulamento
# - Polimorfismo
#
# (Quadro Branco.)
